# %%
import os
import pandas as pd

# %%
filepath = os.path.join(".", "Superstore.csv")

# %%
df = pd.read_csv(filepath, encoding='latin')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ## Qual o total de lucro obtido?

# %%
df.Profit
# Out:
# 0        41.9136
# 1       219.5820
# 2         6.8714
# 3      -383.0310
# 4         2.5164
#           ...
# 9989      4.1028
# 9990     15.6332
# 9991     19.3932
# 9992     13.3200
# 9993     72.9480
# Name: Profit, Length: 9994, dtype: float64

# %%
df.Profit.sum()
# Out:
# np.float64(286397.0217)

# %% [markdown]
# ## Quais os 5 estados com maior faturamento?

# %%
cols = ["Profit", "State"]

# %%
df.sort_values(by="Profit", ascending=False)[cols].head()
# Out:
#          Profit       State
# 6826  8399.9760     Indiana
# 8153  6719.9808  Washington
# 4190  5039.9856    Delaware
# 9039  4946.3700    Michigan
# 4098  4630.4755   Minnesota

# %% [markdown]
# ## Quais os 5 estados com maior prejuízo?

# %%
cols = ["Profit", "State"]

# %%
df.sort_values(by="Profit")[cols].head()
# Out:
#          Profit           State
# 7772 -6599.9780            Ohio
# 683  -3839.9904  North Carolina
# 9774 -3701.8928           Texas
# 3011 -3399.9800        Colorado
# 4991 -2929.4845        Illinois

# %% [markdown]
# ## Quantos pedidos foram feitos por tipo de envio?

# %%
df["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64
