# %%
# %pip install pandas matplotlib scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.9 kB 991.0 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.9 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 465.1 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/111.1 kB ? eta -:--:--
#      ----------- ---------------------------- 30.7/111.1 kB ? eta -:--:--
#      ------------------------- ------------- 71.7/111.1 kB 1.3 MB/s eta 0:00:01
#      ----------------------------------- -- 102.4/111.1 kB 1.5 MB/s eta 0:00:01
#      ------------------------------------ 111.1/111.1 kB 715.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.8 kB 991.0 kB/s eta 0:00:01
#      --------------------------------- ------ 51.2/60.8 kB 1.3 MB/s eta 0:00:01
# ...
