# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv", sep=";")
data
# Out:
#                       Nome     Mês     Último     Máxima     Mínima Variação  \
# 0                     Ouro  Dez 25   3.449,70   3.453,70   3.448,25   +16,70
# 1                XAU/Dólar     NaN   3.394,20   3.399,30   3.394,20    -3,26
# 2                    Prata  Set 25     38,770     38,773     38,653   +0,077
# 3                    Cobre  Dez 25     4,4938     4,5017     4,4928  -0,0067
# 4                  Platina  Out 25   1.345,40   1.348,70   1.342,90    -1,85
# 5                  Paládio  Dez 25   1.107,25   1.108,75   1.103,00    +0,50
# 6             Petróleo WTI  Out 25      63,80      63,84      63,72    -0,04
# 7           Petróleo Brent  Nov 25      67,13      67,22      67,06    -0,08
# 8              Gás Natural  Out 25      2,874      2,875      2,863   -0,004
# 9      Óleo de Aquecimento  Out 25     2,2783     2,2852     2,2768  -0,0034
# 10           Gasolina RBOB  Out 25     1,9617     1,9634     1,9604  -0,0004
# ...
