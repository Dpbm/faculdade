# %%
# !pip install matplotlib seaborn scikit-learn pandas --break-system-packages

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
def get_na(data):
    for column in data.columns:
        print("column: ", column, "; total=", data[column].isna().sum())

# %%
def check_proportion(data):
    sns.countplot(data=data, x="alive", hue="sex", stat="percent")
    plt.show()

# %%
data = sns.load_dataset("titanic")

# %%
check_proportion(data)

# %%
data.deck = data.deck.cat.add_categories("H").fillna("H")
data.embark_town = data.embark_town.fillna("O")
data.embarked = data.embark_town.fillna("N")

data = data.dropna()
get_na(data)

data.shape
# Out:
# column:  survived ; total= 0
# column:  pclass ; total= 0
# column:  sex ; total= 0
# column:  age ; total= 0
# column:  sibsp ; total= 0
# column:  parch ; total= 0
# column:  fare ; total= 0
# column:  embarked ; total= 0
# column:  class ; total= 0
# column:  who ; total= 0
# column:  adult_male ; total= 0
# column:  deck ; total= 0
# column:  embark_town ; total= 0
# column:  alive ; total= 0
# column:  alone ; total= 0
# (714, 15)

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare     embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500  Southampton  Third
# 1         1       1  female  38.0      1      0  71.2833    Cherbourg  First
# 2         1       3  female  26.0      0      0   7.9250  Southampton  Third
# 3         1       1  female  35.0      1      0  53.1000  Southampton  First
# 4         0       3    male  35.0      0      0   8.0500  Southampton  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True    H  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False    H  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True    H  Southampton    no   True

# %%
sns.countplot(data=data, x="alive", hue="sex")
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
data.embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
get_na(data)
# Out:
# column:  survived ; total= 0
# column:  pclass ; total= 0
# column:  sex ; total= 0
# column:  age ; total= 177
# column:  sibsp ; total= 0
# column:  parch ; total= 0
# column:  fare ; total= 0
# column:  embarked ; total= 2
# column:  class ; total= 0
# column:  who ; total= 0
# column:  adult_male ; total= 0
# column:  deck ; total= 0
# column:  embark_town ; total= 2
# column:  alive ; total= 0
# column:  alone ; total= 0

# %%
data.corr(numeric_only=True).style.background_gradient()
# Out:
# <style type="text/css">
# #T_44818_row0_col0, #T_44818_row1_col1, #T_44818_row2_col2, #T_44818_row3_col3, #T_44818_row4_col4, #T_44818_row5_col5, #T_44818_row6_col6, #T_44818_row7_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_44818_row0_col1, #T_44818_row4_col6 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_44818_row0_col2, #T_44818_row6_col3 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_44818_row0_col3 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_44818_row0_col4, #T_44818_row1_col3, #T_44818_row1_col6 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_44818_row0_col5, #T_44818_row5_col0 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_44818_row0_col6, #T_44818_row1_col2, #T_44818_row1_col5, #T_44818_row3_col7, #T_44818_row4_col7, #T_44818_row5_col1, #T_44818_row6_col0, #T_44818_row7_col3, #T_44818_row7_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_44818_row0_col7, #T_44818_row5_col6 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_44818_row1_col0 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_44818_row1_col4 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_44818_row1_col7 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_44818_row2_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_44818_row2_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_44818_row2_col3 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_44818_row2_col4 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_44818_row2_col5, #T_44818_row6_col1, #T_44818_row7_col2 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_44818_row2_col6 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_44818_row2_col7, #T_44818_row4_col5 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_44818_row3_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_44818_row3_col1 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_44818_row3_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_44818_row3_col4, #T_44818_row4_col3 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_44818_row3_col5 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_44818_row3_col6 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_44818_row4_col0 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_44818_row4_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_44818_row4_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_44818_row5_col2 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_44818_row5_col3 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_44818_row5_col4 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_44818_row5_col7 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_44818_row6_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_44818_row6_col4 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_44818_row6_col5 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_44818_row6_col7 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_44818_row7_col0 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_44818_row7_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_44818_row7_col5 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_44818_row7_col6 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_44818">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44818_level0_col0" class="col_heading level0 col0" >survived</th>
#       <th id="T_44818_level0_col1" class="col_heading level0 col1" >pclass</th>
#       <th id="T_44818_level0_col2" class="col_heading level0 col2" >age</th>
#       <th id="T_44818_level0_col3" class="col_heading level0 col3" >sibsp</th>
#       <th id="T_44818_level0_col4" class="col_heading level0 col4" >parch</th>
#       <th id="T_44818_level0_col5" class="col_heading level0 col5" >fare</th>
#       <th id="T_44818_level0_col6" class="col_heading level0 col6" >adult_male</th>
#       <th id="T_44818_level0_col7" class="col_heading level0 col7" >alone</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44818_level0_row0" class="row_heading level0 row0" >survived</th>
#       <td id="T_44818_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_44818_row0_col1" class="data row0 col1" >-0.338481</td>
#       <td id="T_44818_row0_col2" class="data row0 col2" >-0.077221</td>
#       <td id="T_44818_row0_col3" class="data row0 col3" >-0.035322</td>
#       <td id="T_44818_row0_col4" class="data row0 col4" >0.081629</td>
#       <td id="T_44818_row0_col5" class="data row0 col5" >0.257307</td>
#       <td id="T_44818_row0_col6" class="data row0 col6" >-0.557080</td>
#       <td id="T_44818_row0_col7" class="data row0 col7" >-0.203367</td>
#     </tr>
#     <tr>
#       <th id="T_44818_level0_row1" class="row_heading level0 row1" >pclass</th>
#       <td id="T_44818_row1_col0" class="data row1 col0" >-0.338481</td>
#       <td id="T_44818_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_44818_row1_col2" class="data row1 col2" >-0.369226</td>
#       <td id="T_44818_row1_col3" class="data row1 col3" >0.083081</td>
#       <td id="T_44818_row1_col4" class="data row1 col4" >0.018443</td>
#       <td id="T_44818_row1_col5" class="data row1 col5" >-0.549500</td>
#       <td id="T_44818_row1_col6" class="data row1 col6" >0.094035</td>
#       <td id="T_44818_row1_col7" class="data row1 col7" >0.135207</td>
#     </tr>
#     <tr>
#       <th id="T_44818_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_44818_row2_col0" class="data row2 col0" >-0.077221</td>
#       <td id="T_44818_row2_col1" class="data row2 col1" >-0.369226</td>
#       <td id="T_44818_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_44818_row2_col3" class="data row2 col3" >-0.308247</td>
#       <td id="T_44818_row2_col4" class="data row2 col4" >-0.189119</td>
#       <td id="T_44818_row2_col5" class="data row2 col5" >0.096067</td>
#       <td id="T_44818_row2_col6" class="data row2 col6" >0.280328</td>
#       <td id="T_44818_row2_col7" class="data row2 col7" >0.198270</td>
#     </tr>
#     <tr>
#       <th id="T_44818_level0_row3" class="row_heading level0 row3" >sibsp</th>
#       <td id="T_44818_row3_col0" class="data row3 col0" >-0.035322</td>
#       <td id="T_44818_row3_col1" class="data row3 col1" >0.083081</td>
#       <td id="T_44818_row3_col2" class="data row3 col2" >-0.308247</td>
#       <td id="T_44818_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_44818_row3_col4" class="data row3 col4" >0.414838</td>
#       <td id="T_44818_row3_col5" class="data row3 col5" >0.159651</td>
#       <td id="T_44818_row3_col6" class="data row3 col6" >-0.253586</td>
#       <td id="T_44818_row3_col7" class="data row3 col7" >-0.584471</td>
#     </tr>
#     <tr>
#       <th id="T_44818_level0_row4" class="row_heading level0 row4" >parch</th>
#       <td id="T_44818_row4_col0" class="data row4 col0" >0.081629</td>
#       <td id="T_44818_row4_col1" class="data row4 col1" >0.018443</td>
#       <td id="T_44818_row4_col2" class="data row4 col2" >-0.189119</td>
#       <td id="T_44818_row4_col3" class="data row4 col3" >0.414838</td>
#       <td id="T_44818_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_44818_row4_col5" class="data row4 col5" >0.216225</td>
#       <td id="T_44818_row4_col6" class="data row4 col6" >-0.349943</td>
#       <td id="T_44818_row4_col7" class="data row4 col7" >-0.583398</td>
#     </tr>
#     <tr>
#       <th id="T_44818_level0_row5" class="row_heading level0 row5" >fare</th>
#       <td id="T_44818_row5_col0" class="data row5 col0" >0.257307</td>
#       <td id="T_44818_row5_col1" class="data row5 col1" >-0.549500</td>
#       <td id="T_44818_row5_col2" class="data row5 col2" >0.096067</td>
#       <td id="T_44818_row5_col3" class="data row5 col3" >0.159651</td>
#       <td id="T_44818_row5_col4" class="data row5 col4" >0.216225</td>
#       <td id="T_44818_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_44818_row5_col6" class="data row5 col6" >-0.182024</td>
#       <td id="T_44818_row5_col7" class="data ro
